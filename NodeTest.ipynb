# %%
import numpy as np
import nengo
import nengo.spa as spa
import world
import kitchen
import nodes

import matplotlib.pyplot as plt
# %matplotlib inline

D = 128

test_world = kitchen.get_kitchen()

objects = ['KETTLE', 'TAP', 'WATER', 'COUNTER']
action_set = ['FILL_KETTLE_FROM_TAP', 'PUT_KETTLE_UNDER_TAP', 'BOIL_KETTLE', 'PLUG_IN_KETTLE','UNPLUG_KETTLE']

motor_vocab = spa.Vocabulary(D)
    
for action in action_set:
    motor_vocab.parse(action)
    
for obj in objects:
    motor_vocab.parse(obj)

motor_sys = nodes.MotorSystem(motor_vocab, test_world)

with spa.SPA() as model:
    model.action = spa.Buffer(dimensions=D, vocab=motor_vocab)
    model.obj = spa.Buffer(dimensions=D, vocab=motor_vocab)
    model.motor = nengo.Node(motor_sys, size_in=2*D, size_out=1)
    
    def set_action(t):
        return 'UNPLUG_KETTLE'

    def set_obj(t):
        return 'KETTLE'
    
    model.inp = spa.Input(action=set_action, obj=set_obj)
    
    nengo.Connection(model.action.state.output, model.motor[D:])
    nengo.Connection(model.obj.state.output, model.motor[:D])
    
    act_probe = nengo.Probe(model.action.state.output, synapse=0.03)
    obj_probe = nengo.Probe(model.obj.state.output, synapse=0.03)
    mot_probe = nengo.Probe(model.motor)
    
def plot(sim):
    fig = plt.figure(figsize=(18,12))

    p1 = fig.add_subplot(3,1,1)
    p1.plot(sim.trange(), model.similarity(sim.data, act_probe))
    p1.legend(model.get_output_vocab('action').keys, fontsize='medium', bbox_to_anchor=(1, -0.15), ncol=6)
    p1.set_ylabel('Action')

    p2 = fig.add_subplot(3,1,2)
    p2.plot(sim.trange(), model.similarity(sim.data, obj_probe))
    p2.legend(model.get_output_vocab('obj').keys, fontsize='medium', bbox_to_anchor=(1, -0.15), ncol=7)
    p2.set_ylabel('Object')

    p3 = fig.add_subplot(3,1,3)
    p3.plot(sim.trange(), sim.data[mot_probe])
    p3.set_ylabel('Motor')
    
sim = nengo.Simulator(model)
sim.reset()
sim.run(1)

plot(sim)
# Out:
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# performing action UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [####                          7%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [#####                         8%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [######                        9%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [######                       11%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [#######                      12%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [########                     13%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [########                     14%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [#########                    15%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [##########                   16%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [##########                   17%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [###########                  18%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############                 19%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############                 20%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [#############                22%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [##############               23%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [###############              24%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [###############              25%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [################             26%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [#################            27%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [#################            28%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [##################           29%                              ] ETA: 0:00:02integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [###################          30%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [###################          31%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [####################         33%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [#####################        34%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [#####################        35%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [######################       36%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [#######################      37%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [#######################      38%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [########################     39%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [#########################    40%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [#########################    41%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [##########################   42%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [###########################  44%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [###########################  45%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 46%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 47%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 48%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 49%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 50%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# performing action UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 51%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 52%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 53%                              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 55% #                            ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 56% #                            ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 57% ##                           ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 58% ###                          ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 59% ###                          ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 60% ####                         ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 61% #####                        ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 62% #####                        ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 63% ######                       ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 64% #######                      ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 66% #######                      ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 67% ########                     ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 68% #########                    ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 69% #########                    ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 70% ##########                   ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 71% ###########                  ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 72% ############                 ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 73% ############                 ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 74% #############                ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 75% ##############               ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 77% ##############               ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 78% ###############              ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 79% ################             ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 80% ################             ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 81% #################            ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 82% ##################           ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 83% ##################           ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 84% ###################          ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 85% ####################         ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 86% ####################         ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 88% #####################        ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 89% ######################       ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 90% ######################       ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 91% #######################      ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 92% ########################     ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 93% ########################     ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 94% #########################    ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 95% ##########################   ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 96% ###########################  ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 97% ###########################  ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# [############################ 99% ############################ ] ETA: 0:00:01integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# integrating UNPLUG_KETTLE with KETTLE
# Simulation finished in 0:00:02.
